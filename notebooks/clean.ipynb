# %% [markdown]
# # Clean our dataset: Facebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels as sm
import seaborn as sns

# %% [markdown]
# ## Column 1 - Type
#
# `df.info()` said that this column is a string to we'll have to process in into a numeric. `pd.get_dummies()` will help us with that task.

# %%
display(df['Type'].value_counts())
df[['Type_p', 'Type_s', 'Type_v']] = pd.get_dummies(df['Type'], drop_first=True)

# %% [markdown]
# ## Column 2 Category

# %%
display(df['Category'].value_counts())
df[['Category_act', 'Category_prod']] = pd.get_dummies(df['Category'], drop_first=True)
